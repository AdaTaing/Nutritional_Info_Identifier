# %% [markdown]
# ## Image Download

# %%
pip --version
# Out:
# pip 25.3 from c:\Users\Ada Taing\OneDrive\Documents\Repositories\Nutritional_Info_Identifier\.venv\Lib\site-packages\pip (python 3.12)
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
path_to_images = "../images_raw/.open_images"

# %%
from openimages.download import download_dataset

download_dataset(
    path_to_images,
    ["Apple","Pear", "Orange", "Banana"],
    
    annotation_format=None
)
# Out:
# 2025-12-12  13:07:37 INFO Downloading 114 train images for class 'pear'
# 100%|██████████| 114/114 [00:05<00:00, 21.31it/s]
# 2025-12-12  13:07:44 INFO Downloading 7 validation images for class 'pear'
# 100%|██████████| 7/7 [00:01<00:00,  4.97it/s]
# 2025-12-12  13:07:50 INFO Downloading 33 test images for class 'pear'
# 100%|██████████| 33/33 [00:01<00:00, 17.14it/s]
# {'pear': {'images_dir': 'open_images\\pear\\images'}}

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Ada Taing\OneDrive\Documents\Repositories\Nutritional_Info_Identifier\notebooks

# %%
import os
import shutil
import xml.etree.ElementTree as ET
from openimages.download import download_dataset
from tqdm import tqdm
from sklearn.model_selection import train_test_split

# =====================================
# CONFIG
# =====================================

CLASSES = [
    "Apple",
    "Banana",
    "Orange"
]

DATASET_TYPE = "train"
DOWNLOAD_DIR = "openimages_raw"
OUTPUT_DIR = path_to_images

LIMIT_PER_CLASS = 1000
VAL_SPLIT = 0.2

# =====================================
# STEP 1: DOWNLOAD
# =====================================

print("Downloading classes...")

for cls in CLASSES:

    download_dataset(
        OUTPUT_DIR,
        class_names=[cls],
        annotation_format="pascal",
        limit=LIMIT_PER_CLASS
    )

print("Download complete")
# Out:
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 33
#      29 print("Downloading classes...")
#      31 for cls in CLASSES:
# ---> 33     download_dataset(
#      34         OUTPUT_DIR,
#      35         class_names=[cls],
#      36         annotation_format="pascal",
#      37         limit=LIMIT_PER_CLASS
#      38     )
#      40 print("Download complete")
#
# TypeError: download_dataset() got an unexpected keyword argument 'class_names'

# %%
counts = dataset.count_values("detections.detections.label")
print(counts)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12148\1184801857.py in ?()
# ----> 1 counts = dataset.count_values("detections.detections.label")
#       2 print(counts)
#
# c:\Users\Ada Taing\OneDrive\Documents\Repositories\Nutritional_Info_Identifier\.venv\Lib\site-packages\fiftyone\core\collections.py in ?(self, field_or_expr, expr, safe)
#    8552         """
#    8553         make = lambda field_or_expr: foa.CountValues(
#    8554             field_or_expr, expr=expr, safe=safe
#    8555         )
# -> 8556         return self._make_and_aggregate(make, field_or_expr)
#
# c:\Users\Ada Taing\OneDrive\Documents\Repositories\Nutritional_Info_Identifier\.venv\Lib\site-packages\fiftyone\core\collections.py in ?(self, make, args, _generator)
#   11470                 return agg
# ...
