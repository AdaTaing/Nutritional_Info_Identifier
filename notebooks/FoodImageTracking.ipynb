# %% [markdown]
# Food Image Tracker

# %%
# food classes and their image counts (total in folders, not total uploaded)
foods_with_images = {
    "apple": 1204,
    "pear": 1008,
    "grape": 1034,
    "orange": 822,
    "banana": 1163,
    "acai": 1107,
    "cherry": 1004,
    "strawberry": 1003,
    "blueberry": 1003,
    "raspberry": 1013,
    "blackberry": 1130,
    "cantaloupe": 1009,
    "watermelon": 997,
    "pineapple": 1038,
    "kiwi": 1011,
    "mango": 1026,
    "papaya": 1028,
    "grapefruit": 1013,
    "lemon": 1012,
    "lime": 1011,
    "clementine": 1007,
    "mandarin": 1016,
    "date": 1003,
    "fig": 1013
}

# %%
food_images_uploaded = {
    "apple": 1204,
    "pear": 1008,
    "grape": 516,
    "orange": 411,
    "banana": 581,
    "acai": 553,
    "cherry": 502,
    "strawberry": 501,
    "blueberry": 501,
    "raspberry": 506,
    "blackberry": 565,
    "cantaloupe": 504,
    "watermelon": 0,
    "pineapple": 0,
    "kiwi": 505,
    "mango": 0,
    "papaya": 0,
    "grapefruit": 506,
    "lemon": 506,
    "lime": 505,
    "clementine": 503,
    "mandarin": 508,
    "date": 0,
    "fig": 0
}

# %%
trained_foods = [
    "apple",
    "pear",
    "grape",
    "orange",
    "banana",
    "acai",
    "blueberry"
]
