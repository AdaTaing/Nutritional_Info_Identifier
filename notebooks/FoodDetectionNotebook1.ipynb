# %% [markdown]
# # Food Detection Training

# %%
print("Testing")
# Out:
# Testing

# %%
pip install kaggle
# Out:
# ...
#
#    ---------------------------------------- 0/6 [webencodings]
#    ------------- -------------------------- 2/6 [python-slugify]
#    ------------- -------------------------- 2/6 [python-slugify]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------------- ------------- 4/6 [bleach]
#    -------------------------- ------------- 4/6 [bleach]
# ...

# %%
pip install kagglehub
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
